# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
from pathlib import Path
import pyarrow.parquet as pq

month = 1
year = 2023
path = Path('..') / 'data' / 'raw' / f"citi_rides_{year}_{month:02}.parquet"

table = pq.read_table(path)
rides = table.to_pandas()
rides.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  DC1CB984821DFFF7   classic_bike  2023-01-07 15:36:53.430
# 1  C00CA02971557F16   classic_bike  2023-01-04 19:23:01.234
# 2  C753AE5EBD8458F9   classic_bike  2023-01-20 09:22:19.894
# 3  E4415A543C1972A7   classic_bike  2023-01-24 10:38:01.135
# 4  BD52A87B215877C7  electric_bike  2023-01-13 10:17:38.192
#
#                   ended_at       start_station_name start_station_id  \
# 0  2023-01-07 15:39:45.406     Vesey St & Church St          5216.06
# 1  2023-01-04 19:34:57.151  Lispenard St & Broadway          5391.06
# 2  2023-01-20 10:23:24.255  3 Ave & Schermerhorn St          4437.01
# 3  2023-01-24 10:41:40.749           E 5 St & Ave A          5626.06
# 4  2023-01-13 10:33:59.099         W 54 St & 11 Ave          6955.05
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0       Albany St & Greenwich St        5145.02  40.712220 -74.010472
# 1            St Marks Pl & 1 Ave        5626.13  40.719392 -74.002472
# 2            State St & Smith St        4522.07  40.686832 -73.979677
# 3                 E 1 St & 1 Ave        5593.01  40.724790 -73.984301
# 4  Washington St & Gansevoort St        6039.06  40.768292 -73.992563
#
#      end_lat    end_lng member_casual
# 0  40.709267 -74.013247        member
# 1  40.727791 -73.985649        member
# 2  40.689170 -73.988600        member
# 3  40.723356 -73.988650        member
# 4  40.739323 -74.008119        member

# %%
rides_cp = rides.copy()
rides_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795412 entries, 0 to 1795411
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 178.1+ MB

# %%
time_cols = ['started_at', 'ended_at']
for col in time_cols:
    rides_cp[col] = pd.to_datetime(rides_cp[col], errors='coerce')

# %%
rides_cp['duration'] = rides_cp['ended_at'] - rides_cp['started_at']
rides_cp.head()
# Out:
#             ride_id  rideable_type              started_at  \
# 0  DC1CB984821DFFF7   classic_bike 2023-01-07 15:36:53.430
# 1  C00CA02971557F16   classic_bike 2023-01-04 19:23:01.234
# 2  C753AE5EBD8458F9   classic_bike 2023-01-20 09:22:19.894
# 3  E4415A543C1972A7   classic_bike 2023-01-24 10:38:01.135
# 4  BD52A87B215877C7  electric_bike 2023-01-13 10:17:38.192
#
#                  ended_at       start_station_name start_station_id  \
# 0 2023-01-07 15:39:45.406     Vesey St & Church St          5216.06
# 1 2023-01-04 19:34:57.151  Lispenard St & Broadway          5391.06
# 2 2023-01-20 10:23:24.255  3 Ave & Schermerhorn St          4437.01
# 3 2023-01-24 10:41:40.749           E 5 St & Ave A          5626.06
# 4 2023-01-13 10:33:59.099         W 54 St & 11 Ave          6955.05
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0       Albany St & Greenwich St        5145.02  40.712220 -74.010472
# 1            St Marks Pl & 1 Ave        5626.13  40.719392 -74.002472
# 2            State St & Smith St        4522.07  40.686832 -73.979677
# 3                 E 1 St & 1 Ave        5593.01  40.724790 -73.984301
# 4  Washington St & Gansevoort St        6039.06  40.768292 -73.992563
#
#      end_lat    end_lng member_casual               duration
# 0  40.709267 -74.013247        member 0 days 00:02:51.976000
# 1  40.727791 -73.985649        member 0 days 00:11:55.917000
# 2  40.689170 -73.988600        member 0 days 01:01:04.361000
# 3  40.723356 -73.988650        member 0 days 00:03:39.614000
# 4  40.739323 -74.008119        member 0 days 00:16:20.907000

# %%
rides_cp['duration'].describe().T
# Out:
# count                      1795412
# mean     0 days 00:14:56.528263825
# std      0 days 08:09:42.277669378
# min         0 days 00:00:11.832000
# 25%         0 days 00:04:52.974750
# 50%         0 days 00:08:18.412500
# 75%         0 days 00:14:15.858000
# max       263 days 22:37:05.076000
# Name: duration, dtype: object

# %%
rides_cp["duration"].quantile(0)
rides_cp["duration"].quantile(0.01)
rides_cp["duration"].quantile(0.99)
rides_cp["duration"].quantile(0.999)
# Out:
# Timedelta('0 days 00:00:11.832000')
# Timedelta('0 days 00:01:19.154000')
# Timedelta('0 days 01:00:27.271579999')
# Timedelta('0 days 21:01:27.282577002')

# %%
duration_filter = (rides_cp["duration"] > pd.Timedelta(0)) & (rides_cp["duration"] <= pd.Timedelta(hours=1))
sum(~duration_filter)
# Out:
# 18270

# %%
sorted_df = rides_cp.sort_values(by="started_at", ascending=True)  

# Get the top 10 (smallest) and bottom 10 (largest) values  
top_10 = sorted_df.head(10)  
bottom_10 = sorted_df.tail(10)  

top_10

bottom_10
# Out:
#                   ride_id rideable_type              started_at  \
# 385139   EF87BF79137F2A8C  classic_bike 2022-04-17 14:42:58.905
# 137960   6279BF6511781EEF  classic_bike 2022-05-21 18:16:10.671
# 1635218  FE32B9D5DF164E0F  classic_bike 2022-07-29 04:55:32.536
# 328839   0C632EB7C53DD973  classic_bike 2022-08-07 16:59:45.518
# 1633571  D54F0CD210E5DCD1  classic_bike 2022-09-29 19:47:50.972
# 448080   D475B24D2224194E  classic_bike 2022-10-11 14:22:30.004
# 1239212  109A7C4AFC7F00E1  classic_bike 2022-11-06 17:57:48.518
# 879749   1371D252BF823F8F  classic_bike 2022-12-14 11:43:54.762
# 40496    49762460E71B1340  classic_bike 2022-12-28 09:17:28.882
# 101972   F04D6905667F3109  classic_bike 2022-12-28 09:17:51.549
#
#                        ended_at                start_station_name  \
# 385139  2023-01-06 13:20:03.981            Crescent St & Broadway
# 137960  2023-01-17 10:45:11.995      Wards Meadow Comfort Station
# 1635218 2023-01-02 10:32:09.748                  W 53 St & 10 Ave
# 328839  2023-01-18 11:56:50.565             Broadway & Battery Pl
# 1633571 2023-01-10 22:36:05.769         Kenmare St & Elizabeth St
# 448080  2023-01-12 18:24:18.127  Jerome Ave & E Mosholu Parkway S
# 1239212 2023-01-08 16:10:27.234             Yankee Ferry Terminal
# 879749  2023-01-08 14:08:53.507                Dock St & Front St
# 40496   2023-01-01 09:24:57.541     Flushing Ave & Vanderbilt Ave
# 101972  2023-01-01 07:39:38.879     Flushing Ave & Vanderbilt Ave
# 697380  2023-01-31 23:59:57.154  Linden St & Knickerbocker Ave
# 1303740 2023-01-31 23:59:10.318              Dean St & Hoyt St
#
#         start_station_id                   end_station_name end_station_id  \
# 1016491          5905.14                    E 15 St & 3 Ave        5863.07
# 1434392          8103.05                  E 169 St & Fox St        8024.05
# 1138843          5755.09              Lafayette St & E 8 St        5788.13
# 190018           4519.04       Kosciuszko St & Tompkins Ave        4553.04
# 191058           5584.05                     E 1 St & 1 Ave        5593.01
# 759791           6345.08            Lexington Ave & E 36 St        6313.10
# 1430267          5294.04  Grand St & Samuel Dickstein Plaza        5335.07
# 9340             4895.09                 Dock St & Front St        4903.09
# 697380           4743.04     Putnam Ave & Knickerbocker Ave        4663.06
# 1303740          4446.05                Bond St & Bergen St         4404.1
#
#          start_lat  start_lng    end_lat    end_lng member_casual  \
# 1016491  40.734814 -73.992085  40.734232 -73.986923        member
# 1434392  40.832553 -73.905232  40.827184 -73.893721        casual
# 1138843  40.730494 -73.995721  40.730207 -73.991026        member
# 190018   40.690719 -73.951338  40.691283 -73.945242        member
# 191058   40.725286 -73.981687  40.723356 -73.988650        casual
# 759791   40.747733 -73.974299  40.747574 -73.978801        casual
# 1430267  40.714211 -73.981095  40.715119 -73.984171        member
# 9340     40.701403 -73.986727  40.702709 -73.992530        member
# 697380   40.697140 -73.915660  40.695450 -73.911640        member
# 1303740  40.686444 -73.987591  40.684967 -73.986208        member
#
#                       duration
# 1016491 0 days 00:04:42.003000
# 1434392 0 days 00:03:29.815000
# 1138843 0 days 00:02:58.645000
# 190018  0 days 00:01:46.108000
# 191058  0 days 00:04:00.888000
# 759791  0 days 00:01:56.731000
# 1430267 0 days 00:01:16.657000
# 9340    0 days 00:01:44.387000
# 697380  0 days 00:04:29.415000
# 1303740 0 days 00:01:16.293000

# %%
rides_cp['start_station_name'].nunique()
# Out:
# 1732

# %%
# Data in the file that should not be there, remove all values that should not be there
filter_date_range = (rides_cp['started_at'] >= '2023-01-01') & (rides_cp['started_at'] < '2023-02-01')
sum(~filter_date_range)
# Out:
# 283

# %%
final_filter = duration_filter & filter_date_range
numbers_dropped = final_filter.shape[0] - sum(final_filter)
numbers_dropped
numbers_dropped / final_filter.shape[0] * 100
# Out:
# 18406
# 1.0251685964001578

# %%
rides = rides[final_filter]
rides = rides[['started_at', 'start_station_id']]
rides.sort_values(by="started_at", ascending=True).head()

path = Path('..') / 'data' / 'processed' / f'citi_rides_{year}_{month:02}.parquet'
rides.to_parquet(path, engine="pyarrow", index=False)
# Out:
# C:\Users\nolan\AppData\Local\Temp\ipykernel_22884\4048435997.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   rides = rides[final_filter]
#                       started_at start_station_id
# 1266126  2023-01-01 00:00:13.021          6955.01
# 50310    2023-01-01 00:00:15.653          7634.01
# 564026   2023-01-01 00:00:27.436          4307.13
# 1699037  2023-01-01 00:00:29.074          8528.05
# 1506585  2023-01-01 00:00:49.245          7340.07
